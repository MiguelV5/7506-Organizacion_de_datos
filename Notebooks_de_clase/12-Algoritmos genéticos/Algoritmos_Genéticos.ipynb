# %% [markdown]
# # Problema de las 8 reinas
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Solución por fueza bruta

# %%
'''
Program to solve the "n x n chess board and n queens chess problem" from
MagPi 68 (magpi.cc/JgrHLH)
Date: 13MAY2018
Author: raymond gordon
'''
 
import sys, copy, pprint
 
 
def is_solution(coordinates, dimensions):
    # check if multiple queens on same row
    for x in range(dimensions):
        pos = coordinates[x]
        for next_col in range(x + 1, dimensions):
            next_pos = coordinates[next_col]
            # check if multiple queens on same row
            if pos == next_pos:
                return None
            # check if multiple queens on same diagonal
            if (pos + next_col - x) == next_pos:
                return None
            if (pos - next_col + x) == next_pos:
                return None
    return coordinates
 
 
def print_solution(dim, sol):
    for val in range(dim - 1, -1, -1):
        for y in sol:
            if y == val:
                print('Q ', end='')
            else:
                print('. ', end='')
        print()
    print()

    
 
 
def solve():
    solutions = []
    dim = 0
    while True:
        dim = input('Enter the size of the chess board: ')
        if dim.isdecimal():
            break
        print('An intiger value is required. ', end='')
    dim = int(dim)
    if dim < 4:
        print('No solution exists for a board of dimension', dim, 'x', dim)
        print('Exiting program ...')
        return
 
    # populate this_permutation
    this_permutation = []
    for n in range(dim):
        this_permutation.append(0)
 
    # calculate the number of permutations
    possible_permutations = dim
    for n in range(dim):
        possible_permutations *= dim
 
    # initialize the counter
    #placement_cnt = 0
 
    # go through the permutations searching for all possible solutions
    for n in range(possible_permutations):
        rem = n
        for m in range(dim):
            this_permutation[m] = rem % dim
            rem //= dim
        # is this_permutation a solution?
        result = is_solution(copy.copy(this_permutation), dim)
        if result:
            # was this solution encountered previously?
            if result not in solutions:
                solutions.append(result)
 
    print('\nInvestigated', possible_permutations, 'possibilities.')
    sol_cnt = len(solutions)
    print(sol_cnt, 'solutions found.')
 
    print('\n==========\nSolutions:\n==========')
    print('\n("x" position is position of value in array.\n"y" position is value in array)\n')
    cnt = 0
    for solution in solutions:
        cnt += 1
        print()
        print('Solution', cnt, ':')
        pprint.pprint(solution)
        print_solution(dim, solution)

# %%
solve()
# Out:
# Enter the size of the chess board: 7
#
# Investigated 5764801 possibilities.
# 40 solutions found.
#
# ...
# Solutions:
# ...
#
# ("x" position is position of value in array.
# "y" position is value in array)
#
#
# Solution 1 :
# [5, 3, 1, 6, 4, 2, 0]
# . . . Q . . .
# Q . . . . . .
# . . . . Q . .
# . Q . . . . .
# . . . . . Q .
# . . Q . . . .
# . . . . . . Q
#
#
# Solution 2 :
# [4, 1, 5, 2, 6, 3, 0]
# . . . . Q . .
# . . Q . . . .
# Q . . . . . .
# . . . . . Q .
# . . . Q . . .
# . Q . . . . .
# . . . . . . Q
#
#
# Solution 3 :
# [3, 6, 2, 5, 1, 4, 0]
# . Q . . . . .
# . . . Q . . .
# . . . . . Q .
# Q . . . . . .
# . . Q . . . .
# . . . . Q . .
# . . . . . . Q
#
#
# Solution 4 :
# [2, 4, 6, 1, 3, 5, 0]
# . . Q . . . .
# . . . . . Q .
# . Q . . . . .
# . . . . Q . .
# Q . . . . . .
# . . . Q . . .
# . . . . . . Q
#
#
# Solution 5 :
# [5, 2, 4, 6, 0, 3, 1]
# . . . Q . . .
# Q . . . . . .
# . . Q . . . .
# . . . . . Q .
# . Q . . . . .
# . . . . . . Q
# . . . . Q . .
#
#
# Solution 6 :
# ...

# %% [markdown]
# ### Resultados: Solución por fueza bruta
# Tardó 6 minutos
#
# Enter the size of the chess board: 8
#
# Investigated 134217728 possibilities.
# 92 solutions found.
#
#
# **Solutions:**
#
#
# ("x" position is position of value in array.
# "y" position is value in array)
#
#
# Solution 1 :
# [3, 1, 6, 2, 5, 7, 4, 0]
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
#
#
# Solution 2 :
# [4, 1, 3, 6, 2, 7, 5, 0]
# . . . . . Q . .
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
#
#
# Solution 3 :
# [2, 4, 1, 7, 5, 3, 6, 0]
# . . . Q . . . .
# . . . . . . Q .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . . Q
#
#
# Solution 4 :
# [2, 5, 3, 1, 7, 4, 6, 0]
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
#
#
# Solution 5 :
# [4, 6, 0, 2, 7, 5, 3, 1]
# . . . . Q . . .
# . Q . . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . . Q . . . . .
#
#
# Solution 6 :
# [3, 5, 7, 2, 0, 6, 4, 1]
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Solution 7 :
# [2, 5, 7, 0, 3, 6, 4, 1]
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Solution 8 :
# [4, 2, 7, 3, 6, 0, 5, 1]
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
#
#
# Solution 9 :
# [4, 6, 3, 0, 2, 7, 5, 1]
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Solution 10 :
# [3, 0, 4, 7, 5, 2, 6, 1]
# . . . Q . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
#
#
# Solution 11 :
# [2, 5, 3, 0, 7, 4, 6, 1]
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
#
#
# Solution 12 :
# [3, 6, 4, 2, 0, 5, 7, 1]
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
#
#
# Solution 13 :
# [5, 3, 1, 7, 4, 6, 0, 2]
# . . . Q . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . . Q .
#
#
# Solution 14 :
# [5, 3, 6, 0, 7, 1, 4, 2]
# . . . . Q . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
#
#
# Solution 15 :
# [0, 6, 3, 5, 7, 1, 4, 2]
# . . . . Q . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
#
#
# Solution 16 :
# [5, 7, 1, 3, 0, 6, 4, 2]
# . Q . . . . . .
# . . . . . Q . .
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . Q . . .
#
#
# Solution 17 :
# [5, 1, 6, 0, 3, 7, 4, 2]
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
#
#
# Solution 18 :
# [3, 6, 0, 7, 4, 1, 5, 2]
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
#
#
# Solution 19 :
# [4, 7, 3, 0, 6, 1, 5, 2]
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
#
#
# Solution 20 :
# [3, 7, 0, 4, 6, 1, 5, 2]
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
#
#
# Solution 21 :
# [1, 6, 4, 7, 0, 3, 5, 2]
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
#
#
# Solution 22 :
# [0, 6, 4, 7, 1, 3, 5, 2]
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
#
#
# Solution 23 :
# [1, 4, 6, 3, 0, 7, 5, 2]
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
#
#
# Solution 24 :
# [3, 1, 6, 4, 0, 7, 5, 2]
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
#
#
# Solution 25 :
# [4, 6, 0, 3, 1, 7, 5, 2]
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . Q . . . . .
#
#
# Solution 26 :
# [5, 3, 0, 4, 7, 1, 6, 2]
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
#
#
# Solution 27 :
# [4, 0, 3, 5, 7, 1, 6, 2]
# . . . . Q . . .
# . . . . . . Q .
# . . . Q . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . Q . . . . . .
#
#
# Solution 28 :
# [4, 1, 5, 0, 6, 3, 7, 2]
# . . . . . . Q .
# . . . . Q . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
#
#
# Solution 29 :
# [5, 2, 6, 1, 7, 4, 0, 3]
# . . . . Q . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Solution 30 :
# [1, 6, 2, 5, 7, 4, 0, 3]
# . . . . Q . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
#
#
# Solution 31 :
# [6, 2, 0, 5, 7, 4, 1, 3]
# . . . . Q . . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
#
#
# Solution 32 :
# [4, 0, 7, 5, 2, 6, 1, 3]
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
#
#
# Solution 33 :
# [0, 4, 7, 5, 2, 6, 1, 3]
# . . Q . . . . .
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Solution 34 :
# [2, 5, 7, 0, 4, 6, 1, 3]
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
#
#
# Solution 35 :
# [5, 2, 0, 6, 4, 7, 1, 3]
# . . . . . Q . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
#
#
# Solution 36 :
# [6, 4, 2, 0, 5, 7, 1, 3]
# . . . . . Q . .
# Q . . . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . . Q .
# . . . Q . . . .
#
#
# Solution 37 :
# [6, 2, 7, 1, 4, 0, 5, 3]
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# . . . . . Q . .
#
#
# Solution 38 :
# [4, 2, 0, 6, 1, 7, 5, 3]
# . . . . . Q . .
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# . . Q . . . . .
#
#
# Solution 39 :
# [1, 4, 6, 0, 2, 7, 5, 3]
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . . . Q . . . .
#
#
# Solution 40 :
# [2, 5, 1, 4, 7, 0, 6, 3]
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
#
#
# Solution 41 :
# [5, 0, 4, 1, 7, 2, 6, 3]
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
#
#
# Solution 42 :
# [7, 2, 0, 5, 1, 4, 6, 3]
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# . . Q . . . . .
#
#
# Solution 43 :
# [1, 7, 5, 0, 2, 4, 6, 3]
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . . . Q . . . .
#
#
# Solution 44 :
# [4, 6, 1, 5, 2, 0, 7, 3]
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . Q . . . . .
# . . . . . Q . .
#
#
# Solution 45 :
# [2, 5, 1, 6, 4, 0, 7, 3]
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
#
#
# Solution 46 :
# [5, 1, 6, 0, 2, 4, 7, 3]
# . . . . . . Q .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Solution 47 :
# [2, 6, 1, 7, 5, 3, 0, 4]
# . . . Q . . . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . Q .
#
#
# Solution 48 :
# [5, 2, 6, 1, 3, 7, 0, 4]
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
# . . . Q . . . .
# . . . . . . Q .
#
#
# Solution 49 :
# [3, 1, 6, 2, 5, 7, 0, 4]
# . . . . . Q . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
#
#
# Solution 50 :
# [6, 0, 2, 7, 5, 3, 1, 4]
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
#
#
# Solution 51 :
# [0, 5, 7, 2, 6, 3, 1, 4]
# . . Q . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
#
#
# Solution 52 :
# [2, 7, 3, 6, 0, 5, 1, 4]
# . Q . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Solution 53 :
# [5, 2, 6, 3, 0, 7, 1, 4]
# . . . . . Q . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Solution 54 :
# [6, 3, 1, 7, 5, 0, 2, 4]
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
#
#
# Solution 55 :
# [3, 5, 7, 1, 6, 0, 2, 4]
# . . Q . . . . .
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . Q . .
#
#
# Solution 56 :
# [1, 5, 0, 6, 3, 7, 2, 4]
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
#
#
# Solution 57 :
# [1, 3, 5, 7, 2, 0, 6, 4]
# . . . Q . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
#
#
# Solution 58 :
# [2, 5, 7, 1, 3, 0, 6, 4]
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . Q . .
#
#
# Solution 59 :
# [5, 2, 0, 7, 3, 1, 6, 4]
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Solution 60 :
# [7, 3, 0, 2, 5, 1, 6, 4]
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Solution 61 :
# [3, 7, 0, 2, 5, 1, 6, 4]
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Solution 62 :
# [1, 5, 7, 2, 0, 3, 6, 4]
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . Q . . .
#
#
# Solution 63 :
# [6, 1, 5, 2, 0, 3, 7, 4]
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . . Q . . . .
# . Q . . . . . .
# . . . . Q . . .
#
#
# Solution 64 :
# [2, 5, 1, 6, 0, 3, 7, 4]
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Solution 65 :
# [3, 6, 2, 7, 1, 4, 0, 5]
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
#
#
# Solution 66 :
# [3, 7, 4, 2, 0, 6, 1, 5]
# . Q . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Solution 67 :
# [2, 4, 7, 3, 0, 6, 1, 5]
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Solution 68 :
# [3, 1, 7, 4, 6, 0, 2, 5]
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
#
#
# Solution 69 :
# [4, 6, 1, 3, 7, 0, 2, 5]
# . . . . Q . . .
# . Q . . . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
#
#
# Solution 70 :
# [6, 3, 1, 4, 7, 0, 2, 5]
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . Q .
# . . Q . . . . .
# . . . . . Q . .
#
#
# Solution 71 :
# [7, 1, 3, 0, 6, 4, 2, 5]
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Solution 72 :
# [6, 1, 3, 0, 7, 4, 2, 5]
# . . . . Q . . .
# Q . . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Solution 73 :
# [4, 0, 7, 3, 1, 6, 2, 5]
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# Q . . . . . . .
# . . . Q . . . .
# . . . . . . Q .
# . . . . Q . . .
# . Q . . . . . .
#
#
# Solution 74 :
# [3, 0, 4, 7, 1, 6, 2, 5]
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . Q . . . . . .
#
#
# Solution 75 :
# [4, 1, 7, 0, 3, 6, 2, 5]
# . . Q . . . . .
# . . . . . Q . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
#
#
# Solution 76 :
# [2, 6, 1, 7, 4, 0, 3, 5]
# . . . Q . . . .
# . Q . . . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
#
#
# Solution 77 :
# [2, 0, 6, 4, 7, 1, 3, 5]
# . . . . Q . . .
# . . Q . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
#
#
# Solution 78 :
# [7, 1, 4, 2, 0, 6, 3, 5]
# Q . . . . . . .
# . . . . . Q . .
# . . . . . . . Q
# . . Q . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . Q . . . . . .
# . . . . Q . . .
#
#
# Solution 79 :
# [2, 4, 1, 7, 0, 6, 3, 5]
# . . . Q . . . .
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
#
#
# Solution 80 :
# [2, 4, 6, 0, 3, 1, 7, 5]
# . . . . . . Q .
# . . Q . . . . .
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# Q . . . . . . .
# . . . . . Q . .
# . . . Q . . . .
#
#
# Solution 81 :
# [4, 1, 3, 5, 7, 2, 0, 6]
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
#
#
# Solution 82 :
# [5, 2, 4, 7, 0, 3, 1, 6]
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Solution 83 :
# [4, 7, 3, 0, 2, 5, 1, 6]
# . Q . . . . . .
# . . . . . . . Q
# . . . . . Q . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . Q . . . .
#
#
# Solution 84 :
# [3, 1, 4, 7, 5, 0, 2, 6]
# . . . Q . . . .
# . . . . . . . Q
# . . . . Q . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
#
#
# Solution 85 :
# [3, 5, 0, 4, 1, 7, 2, 6]
# . . . . . Q . .
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . Q . . . . .
#
#
# Solution 86 :
# [5, 2, 0, 7, 4, 1, 3, 6]
# . . . Q . . . .
# . . . . . . . Q
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Solution 87 :
# [4, 2, 0, 5, 7, 1, 3, 6]
# . . . . Q . . .
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . . . Q . .
# . . Q . . . . .
#
#
# Solution 88 :
# [3, 1, 7, 5, 0, 2, 4, 6]
# . . Q . . . . .
# . . . . . . . Q
# . . . Q . . . .
# . . . . . . Q .
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . Q . . .
#
#
# Solution 89 :
# [5, 2, 4, 6, 0, 3, 1, 7]
# . . . . . . . Q
# . . . Q . . . .
# Q . . . . . . .
# . . Q . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . . . Q .
# . . . . Q . . .
#
#
# Solution 90 :
# [5, 3, 6, 0, 2, 4, 1, 7]
# . . . . . . . Q
# . . Q . . . . .
# Q . . . . . . .
# . . . . . Q . .
# . Q . . . . . .
# . . . . Q . . .
# . . . . . . Q .
# . . . Q . . . .
#
#
# Solution 91 :
# [3, 6, 4, 1, 5, 0, 2, 7]
# . . . . . . . Q
# . Q . . . . . .
# . . . . Q . . .
# . . Q . . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . Q . . . .
# . . . . . Q . .
#
#
# Solution 92 :
# [4, 6, 1, 5, 2, 0, 3, 7]
# . . . . . . . Q
# . Q . . . . . .
# . . . Q . . . .
# Q . . . . . . .
# . . . . . . Q .
# . . . . Q . . .
# . . Q . . . . .
# . . . . . Q . .

# %% [markdown]
# ## Codificando algoritmos genéticos de forma manual

# %%
import sys
import math
import random

TAMANO = 8
OBJ = 8
CANTIDAD_HIJOS = 10 # Fijo, siempre pasan 10
POBLACION_INICIAL_MAX = 50 # Mutaciones: [1,50]
PROBABILIDAD_MUTACION = 0.2
CANTIDAD_MAX_GENERACIONES = 500

# %%
class Cromosoma:
    def __init__(self, tamano, reinas = None):
        self.tamano = tamano
        self.aptitud = 0
        if reinas is None:
            self.reinas = list(range(self.tamano)) #[0, 1, 2, 3, 4, 5, 6, 7]
            random.shuffle(self.reinas)
        else:
          self.reinas =  reinas

    def set_reinas(self,reinas):
        self.reinas = reinas
    
    def get_reinas(self):
        return self.reinas

    # define a fitness function
    def fitness(self):
      individual = self.reinas
      collisions = 500#self.tamano
      for item in individual:
          item_index = individual.index(item)
          for elem in individual:
              elem_index = individual.index(elem)
              if item_index != elem_index:
                  if item - (elem_index - item_index) == elem \
                          or (elem_index - item_index) + item == elem:
                      collisions -= 1
      self.aptitud = collisions

    def cruzar(self, parent_2):
      crossover_index = random.randrange(1, len(parent_2.get_reinas())) #The randrange() method returns a randomly selected element from the specified range.    =>  random.randrange(start, stop, step)
      child_1a = self.reinas[:crossover_index]  #return array from start to index, from "parent 1_"
      child_1b = [i for i in parent_2.get_reinas() if i not in child_1a] # second part of the array taken from parent_2
      child_1 = child_1a + child_1b 

      child_2a = parent_2.get_reinas()[crossover_index:]
      child_2b = [i for i in self.reinas if i not in child_2a]
      child_2 = child_2a + child_2b
      return Cromosoma(self.tamano, child_1), Cromosoma(self.tamano, child_2)

    def mutar_individuo(self):
        if random.uniform(0,1) < PROBABILIDAD_MUTACION:
            index = random.randrange(TAMANO)
            newValue = random.randrange(TAMANO)
            self.set_reinas(self.reinas[:index]+[newValue]+self.reinas[index+1:])

# %%
def generar_poblacion(poblacion_inicial, tamano):    
    poblacion = []
    for i in range(poblacion_inicial):
        poblacion.append(Cromosoma(tamano))
    return poblacion

def cruzar(poblacion_inicial, poblacion):
    new_poblacion = []
    for i in range(int(poblacion_inicial/2)):
        individuo_01_index = random.randrange(len(poblacion))
        individuo_02_index = random.randrange(len(poblacion))
        
        individuo_01 = poblacion[individuo_01_index]
        individuo_02 = poblacion[individuo_02_index]

        new_individuo_01, new_individuo_02 = individuo_01.cruzar(individuo_02)
        new_poblacion.append(new_individuo_01)
        new_poblacion.append(new_individuo_02)
    return new_poblacion

def obtener_mejor(poblacion):
    max = 0
    resultado = poblacion[0]
    for cromosoma in poblacion:
        #cromosoma.calcular_aptitud()
        cromosoma.fitness()
        if cromosoma.aptitud > max:
            max = cromosoma.aptitud
            resultado = cromosoma
    return resultado    

# Seleccion por ruleta
def seleccionar(poblacion):
    new_pob = []
    aptitud_total = sum(cromosoma.aptitud for cromosoma in poblacion)
    rand = random.uniform(0,aptitud_total)
    actual = 0
    for i, cromosoma in enumerate(poblacion):
        actual += cromosoma.aptitud
        if actual >= rand:
            new_pob.append(cromosoma)
        if len(new_pob) >= CANTIDAD_HIJOS:
            break
    return new_pob

def mutar_poblacion(poblacion):
    for cromosoma in poblacion:
        cromosoma.mutar_individuo()        
    return poblacion

# %%
def ga(poblacion_inicial, tablero_size):
    # Algoritmo genetico
    poblacion = generar_poblacion(poblacion_inicial, tablero_size)
    mejor = poblacion[0]    
    for i in range(CANTIDAD_MAX_GENERACIONES):
        print("Generación ",i)
        objetivo = obtener_mejor(poblacion)
        if objetivo.aptitud > mejor.aptitud:
            mejor = objetivo
            if mejor.aptitud == 500:
                return objetivo
        print("reinas al princpio",len(poblacion))
        
        poblacion = seleccionar(poblacion)
        
        print("reinas en seleccion",len(poblacion))

        poblacion = cruzar(poblacion_inicial,poblacion)
        print("reinas en cruzamiento",len(poblacion))
        
        poblacion = mutar_poblacion(poblacion)
        print("reinas en mutacion",len(poblacion))
    return mejor

# %%
# function to print out chess board with queens placed in position
def print_board(board_representation):
    def print_x_in_row(row_length, x_position):
        print(''),
        for _ in range(row_length):
            print('---', end = ''),
        print('\n|', end = ''),
        for i in range(row_length):
            if i == x_position:
                print( '{} |'.format('X'), end = ''),
            else:
                print( '  |', end = ''),
        print('', end = '')

    def print_board_bottom(row_length):
        print(''),
        for _ in range(row_length):
            print('---', end = ''),

    num_of_rows = len(board_representation)
    row_length = num_of_rows    # rows == columns in a chessboard

    for row in range(num_of_rows):
        print_x_in_row(row_length, board_representation[row])

    print_board_bottom(row_length)
    print('\n')

# %%
poblacion = 50
solucion = ga(poblacion, 8)
print_board(solucion.reinas)
# Out:
# Generación  0
# reinas al princpio 50
# reinas en seleccion 10
# reinas en cruzamiento 50
# reinas en mutacion 50
# Generación  1
# reinas al princpio 50
# reinas en seleccion 1
# reinas en cruzamiento 50
# reinas en mutacion 50
# Generación  2
# reinas al princpio 50
# reinas en seleccion 10
# reinas en cruzamiento 50
# reinas en mutacion 50
# Generación  3
# reinas al princpio 50
# reinas en seleccion 7
# reinas en cruzamiento 50
# reinas en mutacion 50
# Generación  4
# reinas al princpio 50
# reinas en seleccion 10
# reinas en cruzamiento 50
# reinas en mutacion 50
# Generación  5
# reinas al princpio 50
# reinas en seleccion 10
# reinas en cruzamiento 50
# reinas en mutacion 50
# Generación  6
#
# ------------------------
# |  |  |  |  |X |  |  |  |
# ------------------------
# |  |  |  |  |  |  |X |  |
# ------------------------
# |X |  |  |  |  |  |  |  |
# ------------------------
# |  |  |  |  |  |X |  |  |
# ------------------------
# |  |  |  |  |X |  |  |  |
# ...

# %% [markdown]
# ## Usando una biblioteca de algoritmos geneticos

# %%
# !pip install pyeasyga
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pyeasyga: filename=pyeasyga-0.3.1-py2.py3-none-any.whl size=6806 sha256=3b3e62b2e12e880b20224544cf9fb4ccc9b782d390cc1c4c0c8fe08ce2ca6e79
#   Stored in directory: /root/.cache/pip/wheels/58/fa/2a/493c9d613e1048d4338ce44436a2e1c056b9ffcc75fb79add5
# Successfully built pyeasyga
# ...

# %%
import random
from pyeasyga import pyeasyga

# %%
# setup seed data
seed_data = [0, 1, 2, 3, 4, 5, 6, 7]

# %%
# initialise the GA
ga = pyeasyga.GeneticAlgorithm(seed_data,
                               population_size=200,
                               generations=100,
                               crossover_probability=0.8,
                               mutation_probability=0.2,
                               elitism=True,
                               maximise_fitness=False)

# %%
# define and set function to create a candidate solution representation
def create_individual(data):
    individual = data[:] #make a copy
    random.shuffle(individual) #change the order
    return individual

ga.create_individual = create_individual

# %%
# define and set the GA's crossover operation
def crossover(parent_1, parent_2):
    crossover_index = random.randrange(1, len(parent_1)) #The randrange() method returns a randomly selected element from the specified range.    =>  random.randrange(start, stop, step)
    child_1a = parent_1[:crossover_index]  #return array from start to index, from "parent 1_"
    child_1b = [i for i in parent_2 if i not in child_1a] # second part of the array taken from parent_2
    child_1 = child_1a + child_1b 

    child_2a = parent_2[crossover_index:]
    child_2b = [i for i in parent_1 if i not in child_2a]
    child_2 = child_2a + child_2b

    return child_1, child_2

ga.crossover_function = crossover

# %%
# define and set the GA's mutation operation
def mutate(individual):
    mutate_index1 = random.randrange(len(individual))
    mutate_index2 = random.randrange(len(individual))
    index_val1 = individual[mutate_index1]
    index_val2 = individual[mutate_index2]
    index_val1, index_val2 = index_val2, index_val1 # switch two array elements

ga.mutate_function = mutate

# %%
# define and set the GA's selection operation
def selection(population):
    return random.choice(population) #returns a random element

ga.selection_function = selection

# %%
# define a fitness function
def fitness(individual, data):
    collisions = 0
    for item in individual:
        item_index = individual.index(item)
        for elem in individual:
            elem_index = individual.index(elem)
            if item_index != elem_index:
                if item - (elem_index - item_index) == elem \
                        or (elem_index - item_index) + item == elem:
                    collisions += 1
    return collisions

ga.fitness_function = fitness       # set the GA's fitness function

# %%
ga.run()                            # run the GA

# %%
# print the GA's best solution (valid only if there are no collisions)
if ga.best_individual()[0] == 0:
    print(ga.best_individual())
    print_board(ga.best_individual()[1])
else:
    print("None")
# Out:
# (0, [3, 6, 4, 1, 5, 0, 2, 7])
#
# ------------------------
# |  |  |  |X |  |  |  |  |
# ------------------------
# |  |  |  |  |  |  |X |  |
# ------------------------
# |  |  |  |  |X |  |  |  |
# ------------------------
# |  |X |  |  |  |  |  |  |
# ------------------------
# |  |  |  |  |  |X |  |  |
# ------------------------
# |X |  |  |  |  |  |  |  |
# ------------------------
# |  |  |X |  |  |  |  |  |
# ------------------------
# |  |  |  |  |  |  |  |X |
# ------------------------
