# %% [markdown]
# # <center>Organizaci&oacute;n de Datos</center>
# #### <center>C&aacute;tedra Ing. Rodriguez, Juan Manuel </center>
#
# ## <center>K-Nearest Neighbors</center>
# ### <center> Práctica KNN</center>

# %% [markdown]
# Documentación scikit learn:
#
# https://scikit-learn.org/stable/modules/neighbors.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsRegressor.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.metrics.DistanceMetric.html

# %% [markdown]
# ## K-vecinos más cercanos (KNN)

# %% [markdown]
# El algoritmo K-Nearest Neighbors, o simplemente KNN, funciona obteniendo un punto dado y evaluando sus "k" vecinos para encontrar similitudes.
#
# Se puede utilizar para clasificación o regresión.
#
# La idea se basa en el hecho de que los puntos de datos similares estarán más cerca en el espacio que los puntos que son muy diferentes entre sí.
#
# Veamos el siguiente ejemplo elijamos el punto X y miremos sus 5 vecinos más cercanos:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Se observa que 4 de esos puntos más cercanos son triángulos y sólo uno es un cuadrado. El "grupo" de círculos está demasiado lejos para ser considerado.
#
# Entonces,según la lógica KNN, podemos concluir que el punto X es un triángulo.

# %% [markdown]
# ## Distancias

# %% [markdown]
# La distancia entre dos puntos nos permite determinar si esos puntos son "similares". Cuánto menor es la distancia mas similares serán.
#
# Existen diferentes formas de medir una distancia o una similitud:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# https://towardsdatascience.com/9-distance-measures-in-data-science-918109d069fa

# %% [markdown]
# Veamos unos ejemplos:

# %%
from sklearn.metrics import DistanceMetric

# %%
X=[[0,0],[1,1]]
Y=[[1,1],[2,2]]

euclidean = DistanceMetric.get_metric('euclidean')
chebyshev = DistanceMetric.get_metric('chebyshev')
manhattan = DistanceMetric.get_metric('manhattan')
canberra  = DistanceMetric.get_metric('canberra')

# %%
print(f'euclidea: {euclidean.pairwise(X,Y)[0][0]}')
print(f'manhattan: {manhattan.pairwise(X,Y)[0][0]}')
print(f'chebyshev: {chebyshev.pairwise(X,Y)[0][0]}')
print(f'canberra: {canberra.pairwise(X,Y)[0][0]}')
# Out:
# euclidea: 1.4142135623730951
# manhattan: 2.0
# chebyshev: 1.0
# canberra: 2.0

# %%
manhattan.pairwise(X,Y)
# Out:
# array([[2., 4.],
#        [0., 2.]])

# %% [markdown]
# ## KNN Clasificación

# %% [markdown]
# Vamos a trabajar con el dataset "wine" y mediante KNN intentaremos clasificar la calidad del vino (bueno/malo) según sus características

# %%
#Datos
import numpy as np
import pandas as pd

#Plots
import matplotlib.pyplot as plt
import seaborn as sns

#Modelado
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
#Cargo el dataset
df = pd.read_csv('./datasets/wine.csv')
df.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality
# 0      9.4     bad
# 1      9.8     bad
# 2      9.8     bad
# 3      9.8    good
# 4      9.4     bad

# %%
#Ploteo variables de a pares
sns.pairplot(df,hue='quality')

# %%
#Separar datos y etiquetas
x = df.iloc[:,0:11]
y = df.iloc[:,11]

#Separo conjunto de Train y de Test (80/20)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

# %% [markdown]
# Creamos un modelo con sus parámetros por defecto:

# %%
#Crear el modelo
KNN_Classifier = KNeighborsClassifier()

#vemos sus parámetros
KNN_Classifier.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
#Entrenar el modelo
KNN_Classifier.fit(x_train, y_train)

#Predicción sobre test
y_pred = KNN_Classifier.predict(x_test)

# %%
#Cantidad de aciertos
print('correctas: ', np.sum(y_test == y_pred))
print('total: ', len(y_test))
# Out:
# correctas:  194
# total:  320

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.60625

# %% [markdown]
# Veamos que ocurre si variamos la cantidad de vecinos

# %%
# Variamos la cantidad de vecinos (K)

metrics = [] #cantidad de vecinos y cantidad de aciertos

k_range=range(1, len(x_test)) # vecinos desde 1 hasta cantidad total de puntos en test

for n in k_range:

    knn = KNeighborsClassifier(n_neighbors=n)
    knn.fit(x_train, y_train)
    y_pred = knn.predict(x_test)
    metrics.append((n, (y_test == y_pred).sum()))

# %%
# ploteamos

df_metrics = pd.DataFrame(metrics, columns=['cant_vecinos', 'correctos'])

ax = df_metrics.plot( x='cant_vecinos', 
                      y='correctos',
                      title='Aciertos vs Cantidad de Vecinos'
                     )

ax.set_ylabel("Cantidad de aciertos")
ax.set_xlabel("Cantidad de Vecinos")
plt.show()

# %% [markdown]
# Veamos que ocurre al variar la cantidad de vecinos usando Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

k_range=range(1,30) #canidad de vecinos a probar

k_scores=[] # accuracy para cada K utilizado

for k in k_range:
    #clasificador Knn
    knn=KNeighborsClassifier(n_neighbors=k)
    #uso 10 folds
    scores=cross_val_score(knn,x_train,y_train,cv=10,scoring='accuracy')
    #promedio las 10 métricas
    k_scores.append(scores.mean())

# %%
#ploteamos accuracy vs cantidad de vecinos
plt.plot(k_range, k_scores)
plt.xlabel('Cantidad de Vecinos')
plt.ylabel('Cross Validation Accuracy')
plt.title('Accuracy vs Cantidad de Vecinos')
plt.show()

# %% [markdown]
# ### Optimización de hiperparámetros

# %% [markdown]
# La implementación de scikit learn nos permite setear los siguientes parámetros:
#
# **n_neighbors**: número de vecinos a considerar, por defecto este valor esta seteado en 5.<br>
# **algorithm**:algoritmo utilizado para calcular los vecinos más cercanos<br>
# * ball_tree utilizará [BallTree](https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.BallTree.html#sklearn.neighbors.BallTree)
# * kd_tree : utilizará [KDTree](https://https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KDTree.html#sklearn.neighbors.KDTree)
# * brute : utilizará una búsqueda de fuerza bruta.
#
# **metric**:  métrica a utilizar para el cálculo de la distancia. El valor predeterminado es "minkowski".
# Las métricas válidas dependerán del algorítmo que utilicemos.<br>
# * eculidea
# * manhattan
# * city block
# * ...
#
# **weights**:función de peso utilizada en la predicción<br>
#
# * uniform : pesos uniformes, todos los puntos en cada "vecindario" pesan lo mismo.
# *  distance : el peso de cada punto (vecino) se asigna en forma inversa a su distancia.

# %% [markdown]
# Veamos primero las distancias admitidas por cada algoritmo

# %%
from sklearn.metrics.pairwise import PAIRWISE_DISTANCE_FUNCTIONS
from sklearn.neighbors import BallTree
from sklearn.neighbors import KDTree

#Métricas Válidas
VALID_METRICS = dict(
    ball_tree=BallTree.valid_metrics,
    kd_tree=KDTree.valid_metrics,
    # The following list comes from the sklearn.metrics.pairwise doc string
    brute=list(PAIRWISE_DISTANCE_FUNCTIONS.keys())
    + [ 'braycurtis','canberra','chebyshev','correlation',
        'cosine','dice','hamming','jaccard','kulsinski',
        'mahalanobis','matching','minkowski','rogerstanimoto',
        'russellrao','seuclidean','sokalmichener','sokalsneath',
        'sqeuclidean','yule','wminkowski',
    ],
)

#Ejemplo
for alg in VALID_METRICS:
    print(f'algoritmo: {alg}')
    print(VALID_METRICS[alg])
    print()
# Out:
# algoritmo: ball_tree
# ['euclidean', 'l2', 'minkowski', 'p', 'manhattan', 'cityblock', 'l1', 'chebyshev', 'infinity', 'seuclidean', 'mahalanobis', 'wminkowski', 'hamming', 'canberra', 'braycurtis', 'matching', 'jaccard', 'dice', 'kulsinski', 'rogerstanimoto', 'russellrao', 'sokalmichener', 'sokalsneath', 'haversine', 'pyfunc']
#
# algoritmo: kd_tree
# ['euclidean', 'l2', 'minkowski', 'p', 'manhattan', 'cityblock', 'l1', 'chebyshev', 'infinity']
#
# algoritmo: brute
# ['cityblock', 'cosine', 'euclidean', 'haversine', 'l2', 'l1', 'manhattan', 'precomputed', 'nan_euclidean', 'braycurtis', 'canberra', 'chebyshev', 'correlation', 'cosine', 'dice', 'hamming', 'jaccard', 'kulsinski', 'mahalanobis', 'matching', 'minkowski', 'rogerstanimoto', 'russellrao', 'seuclidean', 'sokalmichener', 'sokalsneath', 'sqeuclidean', 'yule', 'wminkowski']

# %% [markdown]
# Optimizamos los parámetros usando random search cross validation

# %%
from sklearn.model_selection import RandomizedSearchCV

#Grilla de Parámetros
params_grid={ 'n_neighbors':range(1,30), 
              'weights':['distance','uniform'],
              'algorithm':['ball_tree', 'kd_tree', 'brute'],
              'metric':['euclidean','manhattan','chebyshev']
             }

#Clasificador KNN
knn=KNeighborsClassifier()

#Random Search con 10 Folds y 10 iteraciones
rand = RandomizedSearchCV(knn, params_grid, cv=10, scoring='accuracy', n_iter=10, random_state=5)

rand.fit(x_train, y_train)
rand.cv_results_['mean_test_score']
# Out:
# array([0.7255721 , 0.69664124, 0.63880413, 0.64037894, 0.7466966 ,
#        0.68959769, 0.67944759, 0.731047  , 0.7459092 , 0.734172  ])

# %%
#Mejores hiperparametros
print(rand.best_params_)
#Mejor métrica
print(rand.best_score_)
# Out:
# {'weights': 'distance', 'n_neighbors': 22, 'metric': 'euclidean', 'algorithm': 'brute'}
# 0.7466966043307087

# %%
#Mejor estimador
best_knn=rand.best_estimator_

#Predicción con mejor estimador
y_pred=best_knn.predict(x_test)

#Accuracy test
accuracy_score(y_test,y_pred)
# Out:
# 0.75

# %%
from sklearn.metrics import confusion_matrix,classification_report

#Reporte de Clasificación
print(classification_report(y_test,y_pred))

#Matriz de Confusión
cm = confusion_matrix(y_test,y_pred)
sns.heatmap(cm, cmap='Blues',annot=True,fmt='g')
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
#               precision    recall  f1-score   support
#
#          bad       0.72      0.75      0.74       148
#         good       0.78      0.75      0.76       172
#
#     accuracy                           0.75       320
#    macro avg       0.75      0.75      0.75       320
# weighted avg       0.75      0.75      0.75       320
# Text(19.5, 0.5, 'True')

# %% [markdown]
# ## KNN Regresión

# %% [markdown]
# La lógica de regresión KNN es muy similar a lo que se explicó anteriormente para clasificación.
#
# El algoritmo KNN calculará la regresión para el conjunto de datos y luego tomará la cantidad K de vecinos, verificará los resultados de esos vecinos y promediará los resultados, generando una estimación.
#
#     Dada una nueva instancia, devolver el promedio(ponderado) de los valores de sus vecinos

# %% [markdown]
# Vamos a trabajar con el dataset "diamantes" y trataremos de aplicar regresión para predecir el quilate (carat) de los diamantes.

# %% [markdown]
#   **carat**: peso del diamante (0.2--5.01)
#
#   **cut**: calidad del corte (Fair, Good, Very Good, Premium, Ideal)
#
#   **color**: color del diamante,  J (peor) to D (mejor)
#
#   **clarity**: una medida de cuán claro es el diamante(I1 (peor), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (mejor))
#
#   **depth**: porcentaje de profundidad total = z / mean(x, y) = 2 * z / (x + y) (43--79)
#
#   **table**: ancho de la parte superior del diamante en relación con el punto más ancho (43--95)
#
#   **price**: precio en dólares estadounidenses (\$326--\$18,823)
#
#   **x**: longitud en mm (0--10.74)
#
#   **y**: ancho en mm (0--58.9)
#
#   **z**: profundidad en mm (0--31.8)

# %%
#Carga dataset
diam=pd.read_csv('./datasets/diamantes.csv')
diam.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#Gráfico de a pares
sns.pairplot(diam)

# %% [markdown]
# **Correlación**
#
# A partir de este diagrama, podemos ver que *x, y* y *z* podrían ser buenos features ya que sus diagramas de dispersión muestran una posible relación lineal.Analicemos la correlación

# %%
#Heatmap correlación
diam.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b032a_row0_col0, #T_b032a_row1_col1, #T_b032a_row2_col2, #T_b032a_row3_col3, #T_b032a_row4_col4, #T_b032a_row5_col5, #T_b032a_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b032a_row0_col1 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_b032a_row0_col2, #T_b032a_row5_col2 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_b032a_row0_col3 {
#   background-color: #cf453c;
#   color: #f1f1f1;
# }
# #T_b032a_row0_col4, #T_b032a_row4_col0, #T_b032a_row4_col5, #T_b032a_row5_col4 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_b032a_row0_col5, #T_b032a_row5_col0, #T_b032a_row6_col0 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_b032a_row0_col6, #T_b032a_row5_col6 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_b032a_row1_col0, #T_b032a_row1_col2, #T_b032a_row1_col3, #T_b032a_row1_col4, #T_b032a_row1_col5, #T_b032a_row1_col6, #T_b032a_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b032a_row2_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_b032a_row2_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_b032a_row2_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_b032a_row2_col5, #T_b032a_row5_col1 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_b032a_row2_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_b032a_row3_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_b032a_row3_col1 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_b032a_row3_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_b032a_row3_col4 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_b032a_row3_col5 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_b032a_row3_col6 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_b032a_row4_col1 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_b032a_row4_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_b032a_row4_col3 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_b032a_row4_col6 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_b032a_row5_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_b032a_row6_col1 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_b032a_row6_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_b032a_row6_col3 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_b032a_row6_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_b032a_row6_col5 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b032a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >carat</th>
#       <th class="col_heading level0 col1" >depth</th>
#       <th class="col_heading level0 col2" >table</th>
#       <th class="col_heading level0 col3" >price</th>
#       <th class="col_heading level0 col4" >x</th>
#       <th class="col_heading level0 col5" >y</th>
#       <th class="col_heading level0 col6" >z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b032a_level0_row0" class="row_heading level0 row0" >carat</th>
#       <td id="T_b032a_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_b032a_row0_col1" class="data row0 col1" >0.028224</td>
#       <td id="T_b032a_row0_col2" class="data row0 col2" >0.181618</td>
#       <td id="T_b032a_row0_col3" class="data row0 col3" >0.921591</td>
#       <td id="T_b032a_row0_col4" class="data row0 col4" >0.975094</td>
#       <td id="T_b032a_row0_col5" class="data row0 col5" >0.951722</td>
#       <td id="T_b032a_row0_col6" class="data row0 col6" >0.953387</td>
#     </tr>
#     <tr>
#       <th id="T_b032a_level0_row1" class="row_heading level0 row1" >depth</th>
#       <td id="T_b032a_row1_col0" class="data row1 col0" >0.028224</td>
#       <td id="T_b032a_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_b032a_row1_col2" class="data row1 col2" >-0.295779</td>
#       <td id="T_b032a_row1_col3" class="data row1 col3" >-0.010647</td>
#       <td id="T_b032a_row1_col4" class="data row1 col4" >-0.025289</td>
#       <td id="T_b032a_row1_col5" class="data row1 col5" >-0.029341</td>
#       <td id="T_b032a_row1_col6" class="data row1 col6" >0.094924</td>
#     </tr>
#     <tr>
#       <th id="T_b032a_level0_row2" class="row_heading level0 row2" >table</th>
#       <td id="T_b032a_row2_col0" class="data row2 col0" >0.181618</td>
#       <td id="T_b032a_row2_col1" class="data row2 col1" >-0.295779</td>
#       <td id="T_b032a_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_b032a_row2_col3" class="data row2 col3" >0.127134</td>
#       <td id="T_b032a_row2_col4" class="data row2 col4" >0.195344</td>
#       <td id="T_b032a_row2_col5" class="data row2 col5" >0.183760</td>
#       <td id="T_b032a_row2_col6" class="data row2 col6" >0.150929</td>
#     </tr>
#     <tr>
#       <th id="T_b032a_level0_row3" class="row_heading level0 row3" >price</th>
#       <td id="T_b032a_row3_col0" class="data row3 col0" >0.921591</td>
#       <td id="T_b032a_row3_col1" class="data row3 col1" >-0.010647</td>
#       <td id="T_b032a_row3_col2" class="data row3 col2" >0.127134</td>
#       <td id="T_b032a_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_b032a_row3_col4" class="data row3 col4" >0.884435</td>
#       <td id="T_b032a_row3_col5" class="data row3 col5" >0.865421</td>
#       <td id="T_b032a_row3_col6" class="data row3 col6" >0.861249</td>
#     </tr>
#     <tr>
#       <th id="T_b032a_level0_row4" class="row_heading level0 row4" >x</th>
#       <td id="T_b032a_row4_col0" class="data row4 col0" >0.975094</td>
#       <td id="T_b032a_row4_col1" class="data row4 col1" >-0.025289</td>
#       <td id="T_b032a_row4_col2" class="data row4 col2" >0.195344</td>
#       <td id="T_b032a_row4_col3" class="data row4 col3" >0.884435</td>
#       <td id="T_b032a_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_b032a_row4_col5" class="data row4 col5" >0.974701</td>
#       <td id="T_b032a_row4_col6" class="data row4 col6" >0.970772</td>
#     </tr>
#     <tr>
#       <th id="T_b032a_level0_row5" class="row_heading level0 row5" >y</th>
#       <td id="T_b032a_row5_col0" class="data row5 col0" >0.951722</td>
#       <td id="T_b032a_row5_col1" class="data row5 col1" >-0.029341</td>
#       <td id="T_b032a_row5_col2" class="data row5 col2" >0.183760</td>
#       <td id="T_b032a_row5_col3" class="data row5 col3" >0.865421</td>
#       <td id="T_b032a_row5_col4" class="data row5 col4" >0.974701</td>
#       <td id="T_b032a_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_b032a_row5_col6" class="data row5 col6" >0.952006</td>
#     </tr>
#     <tr>
#       <th id="T_b032a_level0_row6" class="row_heading level0 row6" >z</th>
#       <td id="T_b032a_row6_col0" class="data row6 col0" >0.953387</td>
#       <td id="T_b032a_row6_col1" class="data row6 col1" >0.094924</td>
#       <td id="T_b032a_row6_col2" class="data row6 col2" >0.150929</td>
#       <td id="T_b032a_row6_col3" class="data row6 col3" >0.861249</td>
#       <td id="T_b032a_row6_col4" class="data row6 col4" >0.970772</td>
#       <td id="T_b032a_row6_col5" class="data row6 col5" >0.952006</td>
#       <td id="T_b032a_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
#selecciono variables regresoras y a predecir
X = diam[['x', 'y', 'z']]
y = diam.carat

#Separacion Train/test  (80/20)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2, random_state=12)

# %% [markdown]
# **Valores atípicos**
#
# La regresión se ve muy afectada por los valores atípicos, ya que pueden interferir en el cálculo de la pendiente de la curva.

# %%
#Grafico Boxplot Conjunto
sns.set_context('talk')
sns.set_style("darkgrid")

variables=[]
valores=[]

variables =['X']*len(list(X_train.x)) + ['Y']*len(list(X_train.y)) + ['Z']*len(list(X_train.z))

valores=list(X_train.x) + list(X_train.y)+list(X_train.z)

plt.figure(figsize=(10,8))
grafico=sns.boxplot(x=variables,y=valores)
grafico.set(xlabel='Variable')
# Out:
# [Text(0.5, 0, 'Variable')]

# %% [markdown]
# Usaremos la regla 1.5 x IQR: se eliminará todo lo que esté por encima o por debajo de 1.5 veces el rango entre cuantiles.

# %%
#Medidas train
X_train.describe().T
# Out:
#      count      mean       std  min   25%   50%   75%    max
# x  43152.0  5.731283  1.122783  0.0  4.71  5.69  6.54  10.74
# y  43152.0  5.734739  1.150275  0.0  4.72  5.71  6.54  58.90
# z  43152.0  3.538536  0.708813  0.0  2.91  3.53  4.03  31.80

# %%
#Calculo los cuantiles de las variables x,y,z
x_q3, x_q1 = np.percentile(X_train.x, [75 ,25])
y_q3, y_q1 = np.percentile(X_train.y, [75 ,25])
z_q3, z_q1 = np.percentile(X_train.z, [75 ,25])

#Calculo e rango intercuartil de las variables x,y,z
iqr_x = x_q3 - x_q1
iqr_y = y_q3 - y_q1
iqr_z = z_q3 - z_q1

# %%
# Elimino outliers de la variable 'x'
X_train = X_train.query(' x >= (@x_q1 - @iqr_x*1.5) & x <= (@x_q3 + @iqr_x*1.5) ')
y_train = y_train[X_train.index]

# Elimino outliers de la variable 'y'
X_train = X_train.query(' y >= (@y_q1 - @iqr_y*1.5) & y <= (@y_q3 + @iqr_y*1.5) ')
y_train = y_train[X_train.index]

# Elimino outliers de la variable 'z'
X_train = X_train.query(' z >= (@z_q1 - @iqr_z*1.5) & z <= (@z_q3 + @iqr_z*1.5) ')
y_train = y_train[X_train.index]

# %%
#Grafico Boxplot Conjunto
sns.set_context('talk')
sns.set_style("darkgrid")

variables=[]
valores=[]

variables =['X']*len(list(X_train.x)) + ['Y']*len(list(X_train.y)) + ['Z']*len(list(X_train.z))

valores=list(X_train.x) + list(X_train.y)+list(X_train.z)

plt.figure(figsize=(10,8))
grafico=sns.boxplot(x=variables,y=valores)
grafico.set(xlabel='Variable')
# Out:
# [Text(0.5, 0, 'Variable')]

# %%
#Heatmap correlación
X_train.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_2f3bb_row0_col0, #T_2f3bb_row1_col1, #T_2f3bb_row2_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2f3bb_row0_col1 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_2f3bb_row0_col2 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_2f3bb_row1_col0 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_2f3bb_row1_col2, #T_2f3bb_row2_col0, #T_2f3bb_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2f3bb_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >x</th>
#       <th class="col_heading level0 col1" >y</th>
#       <th class="col_heading level0 col2" >z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2f3bb_level0_row0" class="row_heading level0 row0" >x</th>
#       <td id="T_2f3bb_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2f3bb_row0_col1" class="data row0 col1" >0.998605</td>
#       <td id="T_2f3bb_row0_col2" class="data row0 col2" >0.991232</td>
#     </tr>
#     <tr>
#       <th id="T_2f3bb_level0_row1" class="row_heading level0 row1" >y</th>
#       <td id="T_2f3bb_row1_col0" class="data row1 col0" >0.998605</td>
#       <td id="T_2f3bb_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2f3bb_row1_col2" class="data row1 col2" >0.990868</td>
#     </tr>
#     <tr>
#       <th id="T_2f3bb_level0_row2" class="row_heading level0 row2" >z</th>
#       <td id="T_2f3bb_row2_col0" class="data row2 col0" >0.991232</td>
#       <td id="T_2f3bb_row2_col1" class="data row2 col1" >0.990868</td>
#       <td id="T_2f3bb_row2_col2" class="data row2 col2" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
sns.scatterplot(x=X_train.x,y=y_train)
sns.scatterplot(x=X_train.y,y=y_train)
sns.scatterplot(x=X_train.z,y=y_train)

# %%
#Grafico de a pares incluyendo variable a predecir
xy_train_sin_outliers = pd.concat([X_train, y_train], axis=1)
sns.pairplot(xy_train_sin_outliers)

# %%
from sklearn.neighbors import KNeighborsRegressor

# Creo un modelo KNN para regresion y lo ajusto
knn_regressor = KNeighborsRegressor().fit(X_train, y_train)

#Hago una predicción
y_pred=knn_regressor.predict(X_test)

# %%
y_pred
# Out:
# array([0.516, 0.348, 0.396, ..., 0.404, 0.722, 0.318])

# %%
# Performance
performance = pd.DataFrame({'Valor Real': y_test,
                            'Prediccion': y_pred,
                            'Error': y_test - y_pred})
# View
performance.head()
# Out:
#        Valor Real  Prediccion  Error
# 45936        0.51       0.516 -0.006
# 23023        0.35       0.348  0.002
# 34325        0.39       0.396 -0.006
# 38578        0.40       0.402 -0.002
# 15979        1.20       1.220 -0.020

# %%
#Metricas para evaluar modelos
from sklearn import metrics

#Mean Square Error
mse = metrics.mean_squared_error(
        y_true  = y_test,
        y_pred  = y_pred,
        squared = True
       )

print(f"El error (mse) de test es: {mse}")

#Root Mean Square Error
rmse = metrics.mean_squared_error(
        y_true  = y_test,
        y_pred  = y_pred,
        squared = False
       )

print(f"El error (rmse) de test es: {rmse}")
# Out:
# El error (mse) de test es: 0.00046168594734890633
# El error (rmse) de test es: 0.021486878492440596

# %%
#Coef. de Determinación R2
score_knn = knn_regressor.score(X_test, y_test)
score_knn
# Out:
# 0.9979148186843363

# %% [markdown]
# Comparemos la performance con una regresión lineal múltiple

# %%
from sklearn.linear_model import LinearRegression

# Creo un modelo de regresion lineal y lo ajusto
lr_model = LinearRegression().fit(X_train, y_train)

#Hago una predicción
y_pred=lr_model.predict(X_test)

# %%
#Mean Square Error
mse = metrics.mean_squared_error(
        y_true  = y_test,
        y_pred  = y_pred,
        squared = True
       )

print(f"El error (mse) de test es: {mse}")

#Root Mean Square Error
rmse = metrics.mean_squared_error(
        y_true  = y_test,
        y_pred  = y_pred,
        squared = False
       )

print(f"El error (rmse) de test es: {rmse}")
# Out:
# El error (mse) de test es: 0.010297035291397692
# El error (rmse) de test es: 0.10147430852879803

# %%
#Coef. de Determinación R2
score_lr = lr_model.score(X_test, y_test)
score_lr
# Out:
# 0.9534939590003898
